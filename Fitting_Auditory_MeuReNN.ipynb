# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install speechbrain -q
# !pip install nnAudio -q
# !pip install pytorch_lightning -q
# !pip install murenn -q
# !pip install dtw-python -q
# !pip install pytorch_wavelets -q
#!pip install slurmjobs -q
# !pip install fire -q
# !pip install pytorch-lightning -q
# !pip install fire -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.1/760.1 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 1.9 MB/s eta 0:00:00
# ...

# %%
#!git clone https://github.com/lostanlen/lostanlen2023waspaa /content/drive/MyDrive/FittingAuditory/

# %%
import sys
sys.path.append('/content/drive/MyDrive/FittingAuditory/')

# %%
import utils
import student
import teacher
#import slurm

# %%
# %run /content/drive/MyDrive/FittingAuditory/main.py
# Out:
# Job ID: 1
# 2024-07-20 12:22:18.490396 Start.
#
# This script fits a neural network to the output of an auditory filterbank.
#
#
# /content/drive/MyDrive/FittingAuditory/
# speech
# Gabor1D
# 0
#
# h5py version: 3.9.0
# numpy version: 1.25.2
# pandas version: 2.0.3
# pytorch_lightning version: 2.3.3
# torch version: 2.3.1+cu121
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# 2024-07-20 12:22:19.218700 Finished initializing dataset
# Current device:  gpu
# 2024-07-20 12:22:19.327427 Finished initializing model
# ...
